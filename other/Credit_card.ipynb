# %%
import scipy
import sklearn
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from pylab import rcParams
from sklearn.svm import OneClassSVM
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.metrics import classification_report, accuracy_score

rcParams['figure.figsize'] = [14,8]
labels =['Normal', 'Fruad']

# %%
data = pd.read_csv("creditcard.csv", sep=',')
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# ...

# %%
100*data.isnull().sum()/len(data)
# Out:
# Time      0.0
# V1        0.0
# V2        0.0
# V3        0.0
# V4        0.0
# V5        0.0
# V6        0.0
# V7        0.0
# V8        0.0
# V9        0.0
# V10       0.0
# V11       0.0
# V12       0.0
# V13       0.0
# V14       0.0
# V15       0.0
# V16       0.0
# V17       0.0
# V18       0.0
# V19       0.0
# V20       0.0
# V21       0.0
# V22       0.0
# V23       0.0
# V24       0.0
# V25       0.0
# V26       0.0
# V27       0.0
# V28       0.0
# Amount    0.0
# Class     0.0
# dtype: float64

# %%
count_classes = pd.value_counts(data['Class'], sort= True)
count_classes.plot(kind = 'bar', rot = 0)
plt.title('Transaction Class Distribution')
plt.xticks(range(2), labels)
plt.xlabel('Class')
plt.ylabel('Frequency')
print(count_classes)
# Out:
# '0'    284315
# '1'       492
# Name: Class, dtype: int64

# %%
data['Class1'] = data['Class'].apply(lambda x : (x[1]))
data['Class'] = data['Class1']
data = data.drop('Class1', axis=1)
data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
fruad = data[data['Class'] == '1']

normal = data[data['Class'] == '0']

# %%
fruad.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
normal.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
f, (ax1, ax2) = plt.subplots(2,1, sharex = True)
f.suptitle("amount per transaction by class")
bins = 50
ax1.hist(fruad.Amount, bins = bins)
ax1.set_title('Fruad')
ax2.hist(normal.Amount, bins = bins)
ax2.set_title('Normal')
plt.ylabel('No of Transaction')
plt.xlabel('Amount')
plt.xlim(0,20000)
plt.yscale('log')
plt.show()

# %%
f, (ax1, ax2) = plt.subplots(2,1 , sharex= True)
f.suptitle('scatter plot against time')
ax1.scatter(fruad.Time, fruad.Amount, )
ax1.set_title('Fruad')
ax2.scatter(normal.Time, normal.Amount)
ax2.set_title('Normal')
plt.xlabel('Amount')
plt.ylabel('Transaction trime')
plt.show()

# %%
data1= data.sample(frac=0.1, random_state=42)
data.shape
# Out:
# (284807, 31)

# %%
data1.shape
# Out:
# (28481, 31)

# %%
fruad1 = data1[data1['Class']=='1']

normal1 = data1[data1['Class']=='0']
print(fruad1.shape, normal1.shape)
# Out:
# (46, 31) (28435, 31)

# %%
outlier_fraction = 100*len(fruad1)/float(len(normal1))
outlier_fraction
# Out:
# 0.1617724635132759

# %%
co_relation = data1.corr()
top_corr = co_relation.index
plt.figure(figsize=(30,30))
g = sns.heatmap(data[top_corr].corr(), annot = True, cmap = 'RdYlGn')

# %%
x = data1.iloc[:,:30]
y = data1.iloc[:, -1]
print(x.shape, y.shape)
# Out:
# (28481, 30) (28481,)

# %%
classifiers = {
    "Isolation Forest": IsolationForest(n_estimators=100, max_samples=len(x), contamination = outlier_fraction, random_state= 42)
    "Local Outlier Factor": LocalOutlierFactor(n_neighbors=20, algorithm='auto', leaf_size= 30, metric='minkowski', p=2, metric_params=None, contamination=outlier_fraction)
    "SVM": OneClassSVM(kernel='rbf', degree = 3, gamma= 0.1, nu = 0.05, )
}
