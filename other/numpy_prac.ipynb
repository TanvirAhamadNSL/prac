# %%
import numpy as np
a1 = np.array([[1,2,3,4], [5,6,7,8]])
print(type(a1))
print(a1.dtype)
print(a1.shape)
print(a1)
# Out:
# <class 'numpy.ndarray'>
# int64
# (2, 4)
# [[1 2 3 4]
#  [5 6 7 8]]

# %%
a = np.array([1,2,3,4,5,6], dtype = 'float32')
print(a.dtype)
print(a)
# Out:
# float32
# [1. 2. 3. 4. 5. 6.]

# %%
c1 = np.ones((4,3))
d1 = np.zeros((3,2))
d1
# Out:
# array([[0., 0.],
#        [0., 0.],
#        [0., 0.]])

# %%
e1 = np.eye(3)
print(e1)
f1 = np.random.random((2,2))
f1
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# array([[0.60443463, 0.1239113 ],
#        [0.21272871, 0.23250752]])

# %%
print(a1[a1>2])
print(a1>2)
# Out:
# [3 4 5 6 7 8]
# [[False False  True  True]
#  [ True  True  True  True]]

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
x = np.array([20, 30, 30, 30, 20, 20, 50, 20, 20, 30, 40, 40, 40,  50, 60, 60, 90])

plt.hist(x, 10)
plt.show()

# %%
import cv2
img = cv2.imread('eso1907a.jpg')
print(img.shape)
print(img.size)
print(img.dtype)
plt.imshow(img)
# Out:
# (300, 515, 3)
# 463500
# uint8

# %%
lips = img[:120,:]
plt.imshow(lips)

# %%
img2 = img.copy()
img2[:120, :] = lips
plt.imshow(img2)

# %%
r, g, b = cv2.split(img2)
plt.imshow(r)
plt.imshow(g)
plt.imshow(b)
